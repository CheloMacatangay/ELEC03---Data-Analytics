# %% [markdown]
# <h1>ACTIVITY</h1> <hr>

# %%
import numpy as np
import pandas as pd

# %%
bird = pd.read_csv('datasets\\penguins.csv')

# %%
bird
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h1>Descriptive Analytics</h1>

# %%
bird.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
bird.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0
# year               2009.0  2009.0

# %%
bird
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
bird['species'] == 'Adelie'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
bird[bird['species'] == 'Adelie']
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
bird['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
bird['species'] == 'Gentoo'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
bird[bird['species'] == 'Gentoo']
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# ...

# %%
bird[bird['species'] == 'Chinstrap']
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
Adelie_df = bird[bird['species'] == 'Adelie']

# %%
Gentoo_df = bird[bird['species'] == 'Gentoo']

# %%
Chinstrap_df = bird[bird['species'] == 'Chinstrap']

# %%
Adelie_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
Gentoo_df
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# ...

# %%
Chinstrap_df
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
Adelie_df ['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 147    3475.0
# 148    3450.0
# 149    3750.0
# 150    3700.0
# 151    4000.0
# Name: body_mass_g, Length: 152, dtype: float64

# %%
Adelie_df ['body_mass_g'].mean()
# Out:
# 3700.662251655629

# %%
Adelie_df ['flipper_length_mm']
# Out:
# 0      181.0
# 1      186.0
# 2      195.0
# 3        NaN
# 4      193.0
#        ...
# 147    184.0
# 148    195.0
# 149    193.0
# 150    187.0
# 151    201.0
# Name: flipper_length_mm, Length: 152, dtype: float64

# %%
Adelie_df ['flipper_length_mm'].mean()
# Out:
# 189.95364238410596

# %%
Gentoo_df ['body_mass_g']
# Out:
# 152    4500.0
# 153    5700.0
# 154    4450.0
# 155    5700.0
# 156    5400.0
#         ...
# 271       NaN
# 272    4850.0
# 273    5750.0
# 274    5200.0
# 275    5400.0
# Name: body_mass_g, Length: 124, dtype: float64

# %%
Gentoo_df ['body_mass_g'].mean()
# Out:
# 5076.016260162602

# %%
Chinstrap_df ['body_mass_g']
# Out:
# 276    3500.0
# 277    3900.0
# 278    3650.0
# 279    3525.0
# 280    3725.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 68, dtype: float64

# %%
Chinstrap_df ['body_mass_g'].mean()
# Out:
# 3733.0882352941176

# %%
bird
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
(bird['body_mass_g'] >= 5000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
bird['species'] == 'Gentoo'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
bird[(bird['body_mass_g'] >= 5000) & (bird['species'] == 'Gentoo')]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# 159  Gentoo  Biscoe            46.7           15.3              219.0
# 161  Gentoo  Biscoe            46.8           15.4              215.0
# ..      ...     ...             ...            ...                ...
# 267  Gentoo  Biscoe            55.1           16.0              230.0
# 269  Gentoo  Biscoe            48.8           16.2              222.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 153       5700.0    male  2007
# 155       5700.0    male  2007
# ...

# %% [markdown]
# <h1> Cleaning the Data Frame</h1>

# %%
bird.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False           False          False              False
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex   year
# 0          False  False  False
# 1          False  False  False
# ...

# %%
bird.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h1> What to do withh all NULL VALUES?</h1>

# %%
bird ['bill_length_mm'].mean()
# Out:
# 43.9219298245614

# %%
bird ['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %% [markdown]
# <h1> How to fillUp null values</h1>

# %%
bird ['bill_length_mm'] = bird ['bill_length_mm'].fillna(bird ['bill_length_mm'].mean())

# %%
bird.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
bird ['sex'] = bird ['sex'].fillna(bird ['sex'].mode())

# %%
bird.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
bird ['bill_depth_mm'] = bird ['bill_depth_mm'].fillna(bird ['bill_depth_mm'].mean())

# %%
bird.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
bird ['sex'] = bird ['sex'].fillna(bird ['sex'].mode()[0])

# %%
bird.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# year                 0
# dtype: int64

# %%
bird ['flipper_length_mm'] = bird ['flipper_length_mm'].fillna(bird ['flipper_length_mm'].mean())
bird ['body_mass_g'] = bird ['body_mass_g'].fillna(bird ['body_mass_g'].mean())

# %%
bird.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# <h1> DATA TYPES</h1>

# %%
bird.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
bird.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      344.000000     344.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.443643       1.969027          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# <h1> CHANGING DATA TYPES</h1>

# %%
bird['species'] = bird['species'].astype('category')

# %%
bird.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    object
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    int64
# dtypes: category(1), float64(4), int64(1), object(2)
# memory usage: 19.4+ KB

# %%
bird['island'] = bird['island'].astype('category')

# %%
bird.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    int64
# dtypes: category(2), float64(4), int64(1), object(1)
# memory usage: 17.2+ KB

# %%
bird['sex'] = bird['sex'].astype('category')

# %%
bird.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    category
#  7   year               344 non-null    int64
# dtypes: category(3), float64(4), int64(1)
# memory usage: 15.0 KB

# %%
bird
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen        39.10000       18.70000              181.0
# 1       Adelie  Torgersen        39.50000       17.40000              186.0
# 2       Adelie  Torgersen        40.30000       18.00000              195.0
# 3       Adelie  Torgersen        43.92193       17.15117                NaN
# 4       Adelie  Torgersen        36.70000       19.30000              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream        55.80000       19.80000              207.0
# 340  Chinstrap      Dream        43.50000       18.10000              202.0
# 341  Chinstrap      Dream        49.60000       18.20000              193.0
# 342  Chinstrap      Dream        50.80000       19.00000              210.0
# 343  Chinstrap      Dream        50.20000       18.70000              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h3>1. Which species have a bill length greater than 55mm?</h3>

# %%
bird[bird['bill_length_mm'] >55]['species'].value_counts()
# Out:
# species
# Gentoo       3
# Chinstrap    2
# Adelie       0
# Name: count, dtype: int64

# %% [markdown]
# <h4>Base on the given data, the species that have a bill length greater than 55mm are the GENTOO AND CHINSTRAP, while Adelie doesn
# 'nt meet the given question</h4>

# %% [markdown]
# <h3> 2.How many penguins of each species are found on Biscoe island?</h3>

# %%
bird[bird['island'] == 'Biscoe']['species'].value_counts()
# Out:
# species
# Gentoo       124
# Adelie        44
# Chinstrap      0
# Name: count, dtype: int64

# %% [markdown]
# <h4>Based on the data, there are 124 species in Gentoo, 44 species in Adelie and no species Chinstrap that can be found on Biscoe Island</h4>

# %% [markdown]
# <h3>3.How many penguins of each species have a bill length greater than 45 mm??</h3>

# %%
bird[bird['bill_length_mm'] >45] ['species'].value_counts()
# Out:
# species
# Gentoo       100
# Chinstrap     62
# Adelie         3
# Name: count, dtype: int64

# %% [markdown]
# <h4>Based on the question, there are 3 species that have a bill length greater than 45mm. Gentoo have 100, Chinstrap have 62 and Adelie has 3</h4>

# %% [markdown]
# <h3>4. Which species have a body mass greater than 3000 g but a flipper length less than 100 mm?</h3>

# %%
penguin_df = bird[(bird['body_mass_g'] >3000 ) & (bird['flipper_length_mm'] < 100)]['species']

# %%
penguin_df.value_counts()
# Out:
# species
# Adelie       0
# Chinstrap    0
# Gentoo       0
# Name: count, dtype: int64

# %% [markdown]
# <h4>According to the given data, all of them doesn't meet the condition </h4>

# %% [markdown]
# <h3> 5. How many penguins of each sex (Male and Female) are from Torgersen island?</h3>

# %%
bird[bird['island'] == 'Torgersen']['sex'].value_counts()
# Out:
# sex
# male      28
# female    24
# Name: count, dtype: int64

# %% [markdown]
# <h4>According to the given data, there are 28 Male penguins and 24 Female penguns are from Torgersen island</h4>

# %% [markdown]
# <h3> 6.What is the most common sex of Adelie from Torgersen island and recorded in 2007?</h3>

# %%
bird['species'] == 'Adelie'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
bird['island'] == 'Torgersen'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %%
bird[(bird['species'] == 'Adelie') & 
(bird['island'] == 'Torgersen') &
(bird['year']== 2007)]['sex'].mode()[0]
# Out:
# 'male'

# %% [markdown]
# <h4>Based on the data, the common sex of Adelie from Torgersen island and recorded in 2007 is Male</h4>

# %% [markdown]
# <h3>7. What is the most common island for Adelie that is recorded in 2007??</h3>

# %%
bird[(bird['species'] == 'Adelie') &
(bird['year'] == 2007)]['island'].mode()[0]
# Out:
# 'Dream'

# %% [markdown]
# <h4>The most common island for Adelie species that is recorded in 2007 are from the Dream Island</h4>
